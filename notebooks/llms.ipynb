# %%
import ollama

response = ollama.chat(
    model='qwen3.5',
    messages=[
        {'role': 'user', 'content': 'Translate this into portuguese: [Hi, how are you my name is jaime and i live in london]'}
    ]
)

print(response['message']['content'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import ollama
# ----> 3 response = ollama.chat(
#       4     model='qwen3.5',
#       5     messages=[
#       6         {'role': 'user', 'content': 'Translate this into portuguese: [Hi, how are you my name is jaime and i live in london]'}
#       7     ]
#       8 )
#      10 print(response['message']['content'])
#
# File /opt/homebrew/lib/python3.10/site-packages/ollama/_client.py:365, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     318 def chat(
#     319   self,
#     320   model: str = '',
#    (...)
#     330   keep_alive: Optional[Union[float, str]] = None,
#     331 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     332   """
#     333   Create a chat response using the requested model.
#     334
#    (...)
# ...
