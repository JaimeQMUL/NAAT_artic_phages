# %%
# Seeing results of the SummaryTMP
import pandas as pd

df = pd.read_csv('TMP_results/summary/summary_result.csv')
errs=len(df[df['decision']=='ERROR'])
print(f'Number of errors: {errs}')
uniques=df['thermal_range'].unique()
print(f'Unique entries: {uniques}')
df[df['thermal_range']=='psychrophile']
# Out:
# Number of errors: 14
# Unique entries: ['mesophile' 'psychrophile' 'ERROR' 'thermophile']
#          model accession                          phage  \
# 3   gemma4:e4b  YCQ78089    Shewanella phage Persephone
# 15  gemma4:e4b  YCB25778  Escherichia phage vB_EcoA_8D1
# 31  gemma4:e4b  XYS98208         Escherichia phage CCU7
#
#                                              metadata  \
# 3   {"uid": "3153849337", "accession": "YCQ78089",...
# 15  {"uid": "3131198239", "accession": "YCB25778",...
# 31  {"uid": "3040683829", "accession": "XYS98208",...
#
#                           host taxonomic_level  \
# 3   Shewanella oneidensis MR-1          strain
# 15            Escherichia coli         species
# 31            Escherichia coli         species
#
#                                        host_reasoning host_confidence  \
# 3   The metadata explicitly lists the 'host' as 'S...             NaN
# 15  The metadata explicitly contains the key 'host...             NaN
# ...

# %%
df =pd.read_csv('TMP_results/fast/fast_result.csv')
errs=len(df[df['decision']=='ERROR'])
print(f'Number of errors: {errs}')
uniques=df['thermal_range'].unique()
print(f'Unique entries: {uniques}')
df[df['thermal_range']=='psychrophile']
# Out:
# Number of errors: 244
# Unique entries: ['mesophile' '2010-2020' '2018-2023' 'thermophile' '2023-2024' 'ERROR' nan
#  '1999-2014' 'psychrophile' '1990-2020' '2000-2024']
#            model     accession                               phage  \
# 425   gemma4:e4b  YP_009213881      Escherichia phage vB_EcoM_VR26
# 476   gemma4:e4b  YP_007675086                   Cyanophage P-RSM6
# 688   gemma4:e4b      BCU97102             uncultured marine virus
# 689   gemma4:e4b      BCU96367             uncultured marine virus
# 690   gemma4:e4b      BCU93598             uncultured marine virus
# 1160  gemma4:e4b      ATV46299  Lake Baikal phage Baikal-20-5m-C28
# 1234  gemma4:e4b      AGH26674                   Cyanophage P-RSM3
#
#                                                metadata  \
# 425   {"uid": "971760625", "accession": "YP_00921388...
# 476   {"uid": "472341570", "accession": "YP_00767508...
# 688   {"uid": "2033879293", "accession": "BCU97102",...
# ...

# %%
df =pd.read_csv('TMP_results/democratic/democratic_result.csv')
errs=len(df[df['decision']=='ERROR'])
print(f'Number of errors: {errs}')
uniques=df['thermal_range'].unique()
print(f'Unique entries: {uniques}')
df[df['thermal_range']=='psychrophile']
# Out:
# Number of errors: 301
# Unique entries: ['mesophile' 'ERROR' 'thermophile' 'psychrophile' 'none']
#            model     accession                               phage  \
# 425   gemma4:e4b  YP_009213881      Escherichia phage vB_EcoM_VR26
# 460   gemma4:e4b  YP_009030086                  Serratia phage PS2
# 537   gemma4:e4b      WAX22921            Synechococcus phage S-M1
# 688   gemma4:e4b      BCU97102             uncultured marine virus
# 689   gemma4:e4b      BCU96367             uncultured marine virus
# 690   gemma4:e4b      BCU93598             uncultured marine virus
# 1149  gemma4:e4b      AXH72831                  Caudoviricetes sp.
# 1160  gemma4:e4b      ATV46299  Lake Baikal phage Baikal-20-5m-C28
# 1234  gemma4:e4b      AGH26674                   Cyanophage P-RSM3
#
#                                                metadata  \
# 425   {"uid": "971760625", "accession": "YP_00921388...
# 460   {"uid": "639438356", "accession": "YP_00903008...
# ...
